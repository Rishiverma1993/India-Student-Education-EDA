# %%
# This Python 3 environment comes with many helpful analytics libraries installed


import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')
from sklearn.preprocessing import LabelEncoder
import seaborn as sns

# %%
data = pd.read_csv(r"F:\Feynn labs\New folder\data\2015_16_Statewise_Elementary.csv")
data.head()
# Out:
#    AC_YEAR  STATCD          STATNAME  DISTRICTS  BLOCKS  VILLAGES  CLUSTERS  \
# 0  2015-16       1   JAMMU & KASHMIR         22     201      7263      1628
# 1  2015-16       2  HIMACHAL PRADESH         12     124     10120      2243
# 2  2015-16       3            PUNJAB         22     146     13197      1780
# 3  2015-16       4        CHANDIGARH          1      20        84        20
# 4  2015-16       5       UTTARAKHAND         13      95     11989       995
#
#    TOTPOPULAT  P_URB_POP  POPULATION_0_6  ...  USCR35  NOTCH_ASS  TCHINV  \
# 0       12549      20.05           16.01  ...    1014      20491    1946
# 1        6857       8.69           11.14  ...     652      36054    3053
# 2       27704      29.82           10.62  ...    2754      88618   14200
# 3        1055      97.25           11.18  ...     117       1994     218
# 4       10117      21.54           13.14  ...    1147      12608    1024
#
#    TOTCLS1G  TOTCLS2G  TOTCLS3G  TOTCLS4G  TOTCLS5G  TOTCLS6G  TOTCLS7G
# 0     41171     62474      7878       564       495     24326      2001
# 1     38307      6930      6909      6498      5445      6151      2717
# 2     56222     23531     42532      9244      8406     30835      7218
# 3       135       419      2066         0        36      1398         0
# 4     48215     14587      7545     12388      6671      1855      3227
#
# [5 rows x 816 columns]

# %%
data.columns
# Out:
# Index(['AC_YEAR', 'STATCD', 'STATNAME', 'DISTRICTS', 'BLOCKS', 'VILLAGES',
#        'CLUSTERS', 'TOTPOPULAT', 'P_URB_POP', 'POPULATION_0_6',
#        ...
#        'USCR35', 'NOTCH_ASS', 'TCHINV', 'TOTCLS1G', 'TOTCLS2G', 'TOTCLS3G',
#        'TOTCLS4G', 'TOTCLS5G', 'TOTCLS6G', 'TOTCLS7G'],
#       dtype='object', length=816)

# %%
data.dtypes
# Out:
# AC_YEAR      object
# STATCD        int64
# STATNAME     object
# DISTRICTS     int64
# BLOCKS        int64
#               ...
# TOTCLS3G      int64
# TOTCLS4G      int64
# TOTCLS5G      int64
# TOTCLS6G      int64
# TOTCLS7G      int64
# Length: 816, dtype: object

# %%
data.isnull().sum()
# Out:
# AC_YEAR      0
# STATCD       0
# STATNAME     0
# DISTRICTS    0
# BLOCKS       0
#             ..
# TOTCLS3G     0
# TOTCLS4G     0
# TOTCLS5G     0
# TOTCLS6G     0
# TOTCLS7G     0
# Length: 816, dtype: int64

# %%
plt.figure(figsize=(10,12))
plt.xticks(rotation='vertical')
plt.xlabel('Population', fontsize=14)
plt.ylabel('States In India', fontsize=14)
plt.title("Population wrt to States in India", fontsize=16)
sns.barplot(data['TOTPOPULAT'],data['STATNAME'])
plt.show()

# %%
col=['STATNAME','OVERALL_LI','FEMALE_LIT','MALE_LIT','SEXRATIO','DISTRICTS','TOTPOPULAT','P_URB_POP','P_RUR_POP','AREA_SQKM','SCHTOT','SCHTOTG','SCHTOTGR','SCHTOTPR','ENRTOT','ENRTOTG','ENRTOTGR', 
       'ENRTOTPR', 'TCHTOTG', 'TCHTOTP', 'SCLSTOT', 'STCHTOT', 'ROADTOT', 'SPLAYTOT', 'SWATTOT',  'SELETOT']

# %%
#df_ele['ENRTOTPR']
data1=pd.DataFrame(data,columns=col)
data1.head()
# Out:
#            STATNAME  OVERALL_LI  FEMALE_LIT  MALE_LIT  SEXRATIO  DISTRICTS  \
# 0   JAMMU & KASHMIR       68.74       58.01     78.26       883         22
# 1  HIMACHAL PRADESH       83.78       76.60     90.83       974         12
# 2            PUNJAB       76.68       71.34     81.48       893         22
# 3        CHANDIGARH       86.43       81.38     90.54       818          1
# 4       UTTARAKHAND       79.63       70.70     88.33       963         13
#
#    TOTPOPULAT  P_URB_POP  P_RUR_POP  AREA_SQKM  ...  ENRTOTGR  ENRTOTPR  \
# 0       12549      20.05        NaN     222236  ...    951439    515189
# 1        6857       8.69        NaN      55673  ...    547430    277699
# 2       27704      29.82        NaN      50362  ...   1560105    755203
# 3        1055      97.25        NaN        114  ...     17869       386
# 4       10117      21.54        NaN      53483  ...    679723    604115
#
#    TCHTOTG  TCHTOTP  SCLSTOT  STCHTOT  ROADTOT  SPLAYTOT  SWATTOT  SELETOT
# 0    98689    59148     2114     1745    22634     10604    26362     8078
# 1    66338    28524      540     1476    14929     15456    17999    16401
# 2   128034   106425      562     1583    28650     27853    28771    28757
# 3     5437     3801        1        0      201       187      201      201
# 4    65399    42144      259     1558    18214     13768    22836    16514
#
# [5 rows x 26 columns]

# %%
data.loc[18,'TOTPOPULAT'] = data.loc[18,'TOTPOPULAT']/10

# %%
plt.figure(figsize=(10,12))
sns.barplot(data1['TOTPOPULAT'],data1['STATNAME'], alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('Population', fontsize=14)
plt.ylabel('States in India', fontsize=14)
plt.title("Population wrt states in India", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(10,12))
sns.barplot( data1['SCHTOT'],data1['STATNAME'], alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('No. of Schools', fontsize=14)
plt.ylabel('States in India', fontsize=14)
plt.title("Schools wrt states in India", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(20,12))
for i in range(1,len(data1)):
    plt.subplot(4,9,i)
    plt.title(data1['STATNAME'][i])
    top = ['Gov','pri']
    uttar = data1.loc[data1['STATNAME'] == data1['STATNAME'][i],:]
    value =[float(uttar['SCHTOTG']/uttar['SCHTOT'])*100,float(uttar['SCHTOTPR']/uttar['SCHTOT'])*100]
    plt.pie(value, labels=top, autopct='%1.1f%%',startangle=140)
    plt.axis('equal')
plt.show()

# %%
plt.figure(figsize=(8,12))
sns.barplot( data['OVERALL_LI'],data['STATNAME'], alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('Literacy rate', fontsize=14)
plt.ylabel('States in India', fontsize=14)
plt.title("Literacy Rate wrt states in India", fontsize=16)
plt.show()

# %%
plt.figure(figsize=(8,10))
sns.barplot( data['FEMALE_LIT'],data['STATNAME'], alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('Female Literacy rate', fontsize=14)
plt.ylabel('States in India', fontsize=14)
plt.title("Literacy Rate wrt states in India", fontsize=16)
plt.show()

# %%
#Let us find the difference between the top  3 and bottom 3 statess in female literacy rate.
top_3=data1.sort_values(by='OVERALL_LI', ascending=False).head(3)
bottom_3=data1.sort_values(by='OVERALL_LI', ascending=True).head(3)


#Let us concatenate top and bottom states
top_bottom=pd.concat([top_3, bottom_3], axis=0, sort=False)
top_bottom
# Out:
#              STATNAME  OVERALL_LI  FEMALE_LIT  MALE_LIT  SEXRATIO  DISTRICTS  \
# 31             KERALA       93.91       91.98     96.02      1084         14
# 30        LAKSHADWEEP       92.28       88.25     96.11       946          1
# 14            MIZORAM       91.58       89.40     93.72       975          8
# 9               BIHAR       63.82       53.33     73.39       916         38
# 35          TELANGANA       66.46       57.92     74.95       987         10
# 11  ARUNACHAL PRADESH       66.95       59.57     73.69       920         20
#
#     TOTPOPULAT  P_URB_POP  P_RUR_POP  AREA_SQKM  ...  ENRTOTGR  ENRTOTPR  \
# 31       33388      24.76        NaN      38863  ...    707281   2137218
# 30          64      41.86        NaN         32  ...      5983         0
# 14        1091      40.42        NaN      21081  ...     82420     39836
# 9       103805       8.36        NaN      94163  ...  20363333    506693
# 35         352      38.67        NaN     114840  ...   1824558    944525
# 11        1383      16.48        NaN      83743  ...    186132     51483
#
#     TCHTOTG  TCHTOTP  SCLSTOT  STCHTOT  ROADTOT  SPLAYTOT  SWATTOT  SELETOT
# 31    61636   166596      322      366    15992     12061    16404    15805
# 30      888        0        0        0       33        10       41       41
# 14    11712     6750        7       77     2898      1971     2848     1863
# 9    385728    39230     1521     3396    69162     28295    75544    27963
# 35   127825    99020     3914     4860    38315     24750    38293    36033
# 11    15331     6051      152     1083     2646      1564     3264     1388
#
# [6 rows x 26 columns]

# %%
plt.figure(figsize=(4,6))
sns.barplot( top_bottom['OVERALL_LI'],top_bottom['STATNAME'], alpha=0.8)
plt.xticks(rotation='vertical')
plt.xlabel('Literacy rate', fontsize=14)
plt.ylabel('States in India', fontsize=14)
plt.title("the top  3 and bottom 3 statess in female literacy rate.", fontsize=16)
plt.show()

# %%
#Let us see whther thes states are over crowded or not bychechking the population density.
top_bottom['Pop_DEN']=(top_bottom['TOTPOPULAT']/top_bottom['AREA_SQKM'])*1000
top_bottom['Pop_DEN']
#top_bottom.TOTPOPULAT/top_bottom.AREA_SQKM*1000
# Out:
# 31     859.120500
# 30    2000.000000
# 14      51.752763
# 9     1102.396907
# 35       3.065134
# 11      16.514813
# Name: Pop_DEN, dtype: float64

# %% [markdown]
# #population density is not the factor

# %%
#2.Let us find th difference in female and male literacy rate
top_bottom['Diff_Lit']=top_bottom['MALE_LIT']-top_bottom['FEMALE_LIT']
top_bottom['Diff_Lit']
# Out:
# 31     4.04
# 30     7.86
# 14     4.32
# 9     20.06
# 35    17.03
# 11    14.12
# Name: Diff_Lit, dtype: float64

# %%
top_bottom['Diff_Lit'].plot(y='Diff_Lit',kind='bar', alpha=0.8)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,4))
sns.barplot( top_bottom['STATNAME'],top_bottom['Diff_Lit'], alpha=0.8)
plt.title("Lteracy rate f Vs M")
# Out:
# Text(0.5, 1.0, 'Lteracy rate f Vs M')

# %% [markdown]
# 1.With low literacy states have high differences.
# 2.Bottom states have high male litracy rates but female literacy rates on these states is low,
# 3.which makes over all literacy rate down.

# %%
#3.Let us check urban and rural population in terms of loteracy rate. 
#we dont have data of rural population. Therefore, rural=100-urban
top_bottom['P_RUR_POP']=100-top_bottom['P_URB_POP']
top_bottom['P_RUR_POP']
# Out:
# 31    75.24
# 30    58.14
# 14    59.58
# 9     91.64
# 35    61.33
# 11    83.52
# Name: P_RUR_POP, dtype: float64

# %%
plt.figure(figsize=(10,8))

top_bottom.plot(y = ['P_URB_POP', 'P_RUR_POP'], kind = 'bar')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(10,8))
sns.barplot(top_bottom['STATNAME'], y= top_bottom['P_RUR_POP'])

sns.barplot('P_RUR_POP','STATNAME')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-51-9f4db10f6ba8> in <module>
#       2 sns.barplot(top_bottom['STATNAME'], y= top_bottom['P_RUR_POP'])
#       3
# ----> 4 sns.barplot('P_RUR_POP','STATNAME')
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3167 ):
#    3168
# -> 3169     plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    3170                           estimator, ci, n_boot, units, seed,
#    3171                           orient, color, palette, saturation,
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge)
#    1582                  errwidth, capsize, dodge):
#    1583         """Initialize the plotter."""
# -> 1584         self.establish_variables(x, y, hue, data, orient,
#    1585                                  order, hue_order, units)
#    1586         self.establish_colors(color, palette, saturation)
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     151                 if isinstance(var, str):
#     152                     err = "Could not interpret input '{}'".format(var)
# --> 153                     raise ValueError(err)
#     154
#     155             # Figure out the plotting orientation
#
# ValueError: Could not interpret input 'P_RUR_POP'
